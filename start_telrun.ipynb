# %%
from pyscope.telrun import TelrunOperator

import logging
import yaml
from pyscope import logger
cfg = yaml.safe_load(open('./config/logging.yaml', 'r'))
logging.config.dictConfig(cfg)
logger.setLevel(logging.INFO)

# %%
# Create a TelrunOperator object
telrun = TelrunOperator(gui=False, )
# Out:
# 2024-10-03 23:08:45,818 - pyscope.telrun.telrun_operator - INFO - 217 - Using config file to initialize telrun: D:\RLMT\config\telrun.cfg
# 2024-10-03 23:08:45,820 - pyscope.telrun.init_telrun_dir - INFO - 87 - Initializing a telrun home directory at D:\RLMT
# 2024-10-03 23:08:45,821 - pyscope.telrun.init_telrun_dir - INFO - 102 - Creating empty config files
# 2024-10-03 23:08:45,822 - pyscope.telrun.init_telrun_dir - WARNING - 110 - telrun.cfg already exists, skipping
# 2024-10-03 23:08:45,822 - pyscope.telrun.init_telrun_dir - WARNING - 118 - observatory.cfg already exists, skipping
# 2024-10-03 23:08:45,823 - pyscope.telrun.init_telrun_dir - WARNING - 134 - notifications.cfg already exists, skipping
# 2024-10-03 23:08:45,823 - pyscope.telrun.init_telrun_dir - WARNING - 142 - sync.cfg already exists, skipping
# 2024-10-03 23:08:45,824 - pyscope.telrun.init_telrun_dir - INFO - 144 - Creating images directory
# ...

# %%
# have telrun execute the schedule
telrun.execute_schedule("./schedules/execute/telrun_2024-10-03T19-00-00.ecsv")
# Out:
# 2024-10-03 23:08:51,654 - pyscope.telrun.telrun_operator - INFO - 714 - Executing schedule: ./schedules/execute/telrun_2024-10-03T19-00-00.ecsv
# 2024-10-03 23:08:51,720 - pyscope.telrun.telrun_operator - INFO - 730 - Log of schedule already exists, loading as schedule...
# 2024-10-03 23:08:51,764 - pyscope.telrun.telrun_operator - INFO - 732 - Loaded.
# 2024-10-03 23:08:51,764 - pyscope.telrun.telrun_operator - INFO - 744 - Saving schedule to file: D:\RLMT\logs\telrun_2024-10-03T19-00-00.ecsv
# 2024-10-03 23:08:51,893 - pyscope.telrun.telrun_operator - INFO - 767 - Sun altitude: -59.216 degs (below limit of -6.0), continuing...
# 2024-10-03 23:08:51,895 - pyscope.telrun.telrun_operator - INFO - 851 - CCD temperature: -79.896 degs (below limit of -80.000 with 1.000 tolerance), continuing...
# 2024-10-03 23:08:51,896 - pyscope.telrun.telrun_operator - INFO - 875 - Processing block 1 of 408
# ...
